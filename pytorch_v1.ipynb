# %%
import pandas as pd
import numpy as np

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset, DataLoader

# %%
#Derive the id from the google drive shareable link.
#For the file at hand the link is as below
URL = 'https://drive.google.com/file/d/1NzWWRs_8hSO_IqZikhwhdasRnWOZV2f9/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+URL.split('/')[-2]
#df = pd.read_pickle(path)
df = pd.read_csv(path)
df.head()
# Out:
#              system:index        B1        B2  ...        B8  DN  .geo
# 0  000000000000000009e0_0  0.074800  0.067400  ...  0.187700   1   NaN
# 1  000000000000000009e0_1  0.074800  0.074400  ...  0.204100   1   NaN
# 2  000000000000000009e0_2  0.074800  0.108667  ...  0.158200   1   NaN
# 3  000000000000000009e0_3  0.074800  0.117300  ...  0.153267   1   NaN
# 4  000000000000000009e0_4  0.072933  0.124867  ...  0.176200   1   NaN
#
# [5 rows x 11 columns]

# %%
train_data=df.sample(frac=0.8,random_state=200) #random state is a seed value
test_data=df.drop(train_data.index)

# %%
test_data.shape
# Out:
# (10129, 11)

# %%
X_train = train_data.iloc[:,1:9]
Y_train_multiclass = train_data.iloc[:, 9]
X_test = test_data.iloc[:,1:9]
Y_test_multiclass = test_data.iloc[:, 9]

# %%
def minus1(dn_val):
  return dn_val-1

# %%
Y_train = Y_train_multiclass.apply(minus1)
Y_test = Y_test_multiclass.apply(minus1)

# %%
tensor_x_train = torch.Tensor(X_train.values) # transform to torch tensor
tensor_y_train_float = torch.Tensor(Y_train.values)
tensor_y_train = tensor_y_train_float.type(torch.LongTensor)

tensor_x_test = torch.Tensor(X_test.values) # transform to torch tensor
tensor_y_test_float = torch.Tensor(Y_test.values)
tensor_y_test = tensor_y_test_float.type(torch.LongTensor)

# %%
#tensor_y_train = tensor_y_train.reshape((40514, 1))
#tensor_y_test = tensor_y_test.reshape((10129, 1))

# %%
batch_size = 64

train_dataset = TensorDataset(tensor_x_train,tensor_y_train) # create your datset
train_dataloader = DataLoader(train_dataset, batch_size=batch_size) # create your dataloader

test_dataset = TensorDataset(tensor_x_test,tensor_y_test) # create your datset
test_dataloader = DataLoader(test_dataset, batch_size=batch_size) # create your dataloader

# %%
for X, Y in train_dataloader:
    print("Shape of X [N, C, H, W]: ", X.shape)
    print("Shape of y: ", Y.shape, Y.dtype)
    break
# Out:
# Shape of X [N, C, H, W]:  torch.Size([64, 8])
# Shape of y:  torch.Size([64]) torch.int64

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(8, 10),
            nn.ReLU(),
            nn.Linear(10, 10),
            nn.ReLU(),
            nn.Linear(10, 3),
            nn.Softmax()
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cpu device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=8, out_features=10, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=10, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=3, bias=True)
#     (5): Softmax(dim=None)
#   )
# )

# %%
loss_fn = nn.NLLLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
def train_luca(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        print(y.shape)
        loss = loss_fn(pred, y.view(y.shape[0]) - 1)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        print(y.shape)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test_luca(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# torch.Size([64])
# loss: -0.351290  [    0/40514]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# ...
